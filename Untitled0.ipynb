# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\bangh\documents\인공지능 국비교육\모듈10\movies\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\bangh\documents\인공지능 국비교육\모듈10\movies\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\bangh\documents\인공지능 국비교육\모듈10\movies\lib\site-packages (from html5lib) (0.5.1)
# WARNING: You are using pip version 20.2.3; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\bangh\documents\인공지능 국비교육\모듈10\movies\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ## 1. naver 영화 url 가져오기

# %%
res = requests.get("http://movie.naver.com/movie/point/af/list.nhn")
soup = BeautifulSoup(res.text , 'html5lib')

movie_links = soup.select('a[href]')

movie_links_list = []

for link in movie_links:
  if re.search(r'st=mcode&sword' and r'&target=after', link['href']):
    target_url = r'http://movie.naver.com/movie/point/af/list.nhn'+str(link['href'])
    movie_links_list.append(target_url)
    print(target_url)
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-3-e1530356c78a> in <module>
#       1 res = requests.get("http://movie.naver.com/movie/point/af/list.nhn")
# ----> 2 soup = BeautifulSoup(res.text , 'html5lib')
#       3
#       4 movie_links = soup.select('a[href]')
#       5
#
# c:\users\bangh\appdata\local\programs\python\python38\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     241             builder_class = builder_registry.lookup(*features)
#     242             if builder_class is None:
# --> 243                 raise FeatureNotFound(
#     244                     "Couldn't find a tree builder with the features you "
#     245                     "requested: %s. Do you need to install a parser library?"
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: html5lib. Do you need to install a parser library?

# %% [markdown]
# ## 2. 영화 url를 접속한 후 장르 가져오기

# %%
res = requests.get('http://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189050&target=after')
print(movie_links_list)

genre_list=[]

for movie_url in movie_links_list:
  res = requests.get(movie_url)
  content = res.text
  soup = BeautifulSoup(content , 'html5lib')
  genre = soup.find_all('table', class_='info_area')

  for genre in genre:
    genre_list.append(genre.a.get_text())
    # print(genre.a.get_text())
print(genre_list)

# %% [markdown]
# ## 3. naver 영화에서 평가등을 한 유저정보 가져오기

# %%
res = requests.get("http://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187322&target=after")
content = res.text

soup = BeautifulSoup(content, 'html5lib')

page_links = soup.select('a[href]')
page_link_list = []

for link in page_links:
  if re.search(r'&target=after', link['href']):
    target_url='http://movie.naver.com'+str(link['href'])
    page_link_list.append(target_url)
print(page_link_list)

# %%
def get_movie_link(url):
  res = requests.get(url)
  soup = BeautifulSoup(res.text , 'html5lib')

  movie_links = soup.select('a[href]')

  movie_links_list = []

  for link in movie_links:
    if re.search(r'st=mcode&sword' and r'&target=after', link['href']):
      target_url = r'http://movie.naver.com/movie/point/af/list.nhn'+str(link['href'])
      movie_links_list.append(target_url)

  return movie_links_list


def genre_list(url):
  movie_links_list = get_movie_link(url)
  genre_list=[]
  for movie_url in movie_links_list:
    res = requests.get(movie_url)
    content = res.text
    soup = BeautifulSoup(content , 'html5lib')
    genre = soup.find_all('table', class_='info_area')

    for genre in genre:
      genre_list.append(genre.a.get_text())
      # print(genre.a.get_text())
  return genre_list


def get_user_list(url):
  res = requests.get(url)
  content = res.text

  soup = BeautifulSoup(content, 'html5lib')

  page_links = soup.select('a[href]')
  page_link_list = []

  for link in page_links:
    if re.search(r'&target=after', link['href']):
      target_url='http://movie.naver.com'+str(link['href'])
      page_link_list.append(target_url)
  if len(page_link_list) !=1:
    pop_number = len(page_link_list)-1
    page_link_list.pop(pop_number)

  return page_link_list

# %% [markdown]
# ## 4. url 받아서 데이터를 크롤링

# %%
url_list = get_user_list('http://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187322&target=after&page=1')

if len(url_list) >=2:
  for url in url_list:
    print(url)
    genre_list = genre_list(url)
    print(genre_list)
genre_list = genre_list('http://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187322&target=after&page=1')
